# %%
import requests
from bs4 import BeautifulSoup
import csv

BASE_URL = "https://repositorio.upch.edu.pe"
START_URL = f"{BASE_URL}/handle/20.500.12866/1318/recent-submissions"

# Lista para almacenar los datos
datos = []

def scrape_listing_page(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    #print(soup)
    items = soup.select("li.ds-artifact-item")

    for item in items:
        titulo = item.select_one("div.artifact-title a")
        autores = item.select_one("span.author")
        fecha = item.select_one("span.date")
        publisher = item.select_one("span.publisher")
        resumen = item.select_one("div.artifact-abstract")

        datos.append({
            "titulo": titulo.text.strip() if titulo else "NA",
            "autores": autores.text.strip() if autores else "NA",
            "resumen": resumen.text.strip() if resumen else "NA",
            "editorial": publisher.text.strip() if publisher else "NA",
            "fecha": fecha.text.strip() if fecha else "NA",
            "link": BASE_URL + titulo['href'] if titulo else "NA"
        })

    # Buscar el siguiente botón de paginación
    next_button = soup.select_one("a.next-page-link")
    if next_button:
        next_page_url = BASE_URL + next_button["href"]

        print(f"Avanzando a: {next_page_url}")
        scrape_listing_page(next_page_url)


# Ejecutar el scraping desde la primera página
scrape_listing_page(START_URL)

# Guardar en un archivo CSV
with open("articulos_upch.csv", "w", newline="", encoding="utf-8") as f:
    writer = csv.DictWriter(f, fieldnames=["titulo", "autores", "resumen", "editorial", "fecha", "link"])
    writer.writeheader()
    writer.writerows(datos)

print(f"Se guardaron {len(datos)} artículos en 'articulos_upch.csv'")
# Out:
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=20
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=40
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=60
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=80
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=100
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=120
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=140
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=160
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=180
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=200
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=220
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=240
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=260
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=280
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=300
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=320
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=340
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=360
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=380
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=400
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=420
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=440
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=460
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=480
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=500
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=520
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=540
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=560
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=580
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=600
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=620
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=640
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=660
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=680
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=700
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=720
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=740
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=760
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=780
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=800
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=820
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=840
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=860
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=880
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=900
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=920
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=940
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=960
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=980
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1000
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1020
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1040
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1060
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1080
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1100
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1120
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1140
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1160
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1180
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1200
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1220
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1240
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1260
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1280
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1300
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1320
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1340
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1360
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1380
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1400
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1420
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1440
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1460
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1480
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1500
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1520
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1540
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1560
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1580
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1600
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1620
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1640
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1660
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1680
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1700
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1720
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1740
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1760
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1780
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1800
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1820
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1840
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1860
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1880
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1900
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1920
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1940
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1960
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1980
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2000
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2020
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2040
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2060
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2080
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2100
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2120
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2140
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2160
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2180
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2200
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2220
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2240
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2260
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2280
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2300
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2320
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2340
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2360
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2380
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2400
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2420
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2440
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2460
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2480
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2500
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2520
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2540
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2560
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2580
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2600
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2620
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2640
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2660
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2680
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2700
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2720
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2740
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2760
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2780
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2800
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2820
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2840
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2860
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2880
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2900
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2920
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2940
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2960
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2980
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3000
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3020
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3040
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3060
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3080
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3100
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3120
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3140
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3160
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3180
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3200
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3220
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3240
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3260
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3280
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3300
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3320
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3340
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3360
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3380
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3400
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3420
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3440
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3460
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3480
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3500
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3520
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3540
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3560
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3580
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3600
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3620
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3640
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3660
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3680
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3700
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3720
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3740
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3760
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3780
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3800
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3820
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3840
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3860
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3880
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3900
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3920
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3940
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3960
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3980
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4000
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4020
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4040
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4060
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4080
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4100
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4120
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4140
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4160
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4180
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4200
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4220
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4240
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4260
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4280
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4300
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4320
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4340
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4360
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4380
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4400
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4420
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4440
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4460
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4480
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4500
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4520
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4540
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4560
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4580
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4600
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4620
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4640
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4660
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4680
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4700
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4720
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4740
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4760
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4780
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4800
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4820
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4840
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4860
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4880
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4900
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4920
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4940
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4960
# Avanzando a: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4980
# Se guardaron 4988 artículos en 'articulos_upch.csv'

# %% [markdown]
# ## Documentado

# %%
import requests  # Para realizar solicitudes HTTP al sitio web
from bs4 import BeautifulSoup  # Para analizar y extraer información del HTML
import csv  # Para guardar los datos extraídos en un archivo CSV

# URL base del repositorio UPCH
BASE_URL = "https://repositorio.upch.edu.pe"

# URL de la página donde comienzan las publicaciones recientes
START_URL = f"{BASE_URL}/handle/20.500.12866/1318/recent-submissions"

# Lista donde se almacenarán los datos extraídos de cada artículo
datos = []

def scrape_listing_page(url):
    """
    Función que extrae los datos de los artículos en una página del repositorio.
    Luego, si existe una página siguiente, la procesa también de forma recursiva.

    Parámetros:
        url (str): URL de la página a analizar.
    """
    # Realizamos la solicitud a la URL
    response = requests.get(url)

    # Analizamos el contenido HTML con BeautifulSoup
    soup = BeautifulSoup(response.text, "html.parser")

    # Seleccionamos todos los elementos que contienen artículos
    items = soup.select("li.ds-artifact-item")

    # Iteramos sobre cada artículo encontrado
    for item in items:
        # Extraemos el título del artículo (etiqueta <a> dentro de un div con clase artifact-title)
        titulo = item.select_one("div.artifact-title a")

        # Extraemos los autores (span con clase author)
        autores = item.select_one("span.author")

        # Extraemos la fecha de publicación (span con clase date)
        fecha = item.select_one("span.date")

        # Extraemos la editorial o publicador (span con clase publisher)
        publisher = item.select_one("span.publisher")

        # Extraemos el resumen del artículo (div con clase artifact-abstract)
        resumen = item.select_one("div.artifact-abstract")

        # Añadimos los datos a la lista 'datos', verificando si el elemento existe
        datos.append({
            "titulo": titulo.text.strip() if titulo else "NA",
            "autores": autores.text.strip() if autores else "NA",
            "resumen": resumen.text.strip() if resumen else "NA",
            "editorial": publisher.text.strip() if publisher else "NA",
            "fecha": fecha.text.strip() if fecha else "NA",
            "link": BASE_URL + titulo['href'] if titulo else "NA"
        })

    # Buscamos si hay un botón de paginación para continuar a la siguiente página
    next_button = soup.select_one("a.next-page-link")
    if next_button:
        # Si existe, construimos la URL completa de la siguiente página
        next_page_url = BASE_URL + next_button["href"]

        # Imprimimos en consola para seguimiento del progreso
        print(f"Avanzando a: {next_page_url}")

        # Llamamos recursivamente a la función para continuar con la siguiente página
        scrape_listing_page(next_page_url)

# Iniciamos el scraping desde la URL inicial
scrape_listing_page(START_URL)

# Guardamos los datos recolectados en un archivo CSV
with open("articulos_upch.csv", "w", newline="", encoding="utf-8") as f:
    # Definimos las columnas que tendrá el archivo
    writer = csv.DictWriter(f, fieldnames=["titulo", "autores", "resumen", "editorial", "fecha", "link"])

    # Escribimos la cabecera del archivo CSV
    writer.writeheader()

    # Escribimos todas las filas con los datos recolectados
    writer.writerows(datos)

# Imprimimos un mensaje final con la cantidad de artículos guardados
print(f"Se guardaron {len(datos)} artículos en 'articulos_upch.csv'")

# %% [markdown]
# # Extraccion, ejemplo de solo 2

# %%
import requests
from bs4 import BeautifulSoup
import csv
import time

BASE_URL   = "https://repositorio.upch.edu.pe"
START_URL  = f"{BASE_URL}/handle/20.500.12866/1318/recent-submissions"
MAX_ITEMS  = 80  # ← Número máximo de artículos a extraer para la prueba

# Lista para almacenar los datos
datos = []

def extraer_resumen_completo(url):
    """Visita la página individual del artículo y extrae el resumen completo."""
    try:
        r = requests.get(url)
        soup = BeautifulSoup(r.text, "html.parser")
        tag = soup.select_one("div.simple-item-view-description")
        return tag.get_text(strip=True) if tag else "NA"
    except Exception as e:
        print(f"Error al extraer resumen en {url}: {e}")
        return "NA"

def scrape_listing_page(url):
    """Rastrea la página de listados, pero se detiene cuando datos alcanza MAX_ITEMS."""
    print(f"Scraping listado: {url}")
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "html.parser")
    items = soup.select("li.ds-artifact-item")

    for item in items:
        if len(datos) >= MAX_ITEMS:
            return  # ¡Detiene el scraping en cuanto tengamos suficientes!

        titulo_tag    = item.select_one("div.artifact-title a")
        autores_tag   = item.select_one("span.author")
        fecha_tag     = item.select_one("span.date")
        publisher_tag = item.select_one("span.publisher")

        titulo    = titulo_tag.text.strip() if titulo_tag else "NA"
        link      = BASE_URL + titulo_tag["href"] if titulo_tag else "NA"
        autores   = autores_tag.text.strip() if autores_tag else "NA"
        fecha     = fecha_tag.text.strip() if fecha_tag else "NA"
        editorial = publisher_tag.text.strip() if publisher_tag else "NA"

        resumen = extraer_resumen_completo(link) if link != "NA" else "NA"
        datos.append({
            "titulo":      titulo,
            "autores":     autores,
            "resumen":     resumen,
            "editorial":   editorial,
            "fecha":       fecha,
            "link":        link
        })

        # Pausa breve; para prueba puedes reducirla o eliminarla
        time.sleep(0.2)

    # Si aún no llegamos a MAX_ITEMS, seguimos a la siguiente página
    if len(datos) < MAX_ITEMS:
        next_button = soup.select_one("a.next-page-link")
        if next_button and next_button.get("href"):
            next_url = BASE_URL + next_button["href"]
            scrape_listing_page(next_url)

if __name__ == "__main__":
    scrape_listing_page(START_URL)

    # Guardar resultados en CSV
    with open("articulos_upch_prueba_80.csv", "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=[
            "titulo", "autores", "resumen", "editorial", "fecha", "link"
        ])
        writer.writeheader()
        writer.writerows(datos)

    print(f"Se guardaron {len(datos)} artículos en 'articulos_upch_prueba_80.csv'")
# Out:
# Scraping listado: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions
# Scraping listado: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=20
# Scraping listado: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=40
# Scraping listado: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=60
# Se guardaron 80 artículos en 'articulos_upch_prueba_80.csv'

# %%
# !ls
# !pwd
# Out:
# articulos_upch_prueba.csv  sample_data
# /content

# %% [markdown]
# # Extraccion global

# %%
import requests
from bs4 import BeautifulSoup
import csv
import time
import re

BASE_URL  = "https://repositorio.upch.edu.pe"
START_URL = f"{BASE_URL}/handle/20.500.12866/1318/recent-submissions"

datos = []

def limpia_texto(t):
    # elimina saltos de línea normales, LS (\u2028) y PS (\u2029)
    return re.sub(r'[\r\n\u2028\u2029]', ' ', t).strip()

def extraer_resumen_completo(url):
    try:
        r = requests.get(url)
        soup = BeautifulSoup(r.text, "html.parser")
        tag  = soup.select_one("div.simple-item-view-description")
        txt  = tag.get_text(" ", strip=True) if tag else ""
        return limpia_texto(txt)
    except Exception as e:
        print(f"Error al extraer resumen en {url}: {e}")
        return "NA"

def scrape_listing_page(url):
    print(f"Scraping: {url}")
    r    = requests.get(url)
    soup = BeautifulSoup(r.text, "html.parser")
    items = soup.select("li.ds-artifact-item")

    for item in items:
        titulo_tag    = item.select_one("div.artifact-title a")
        autores_tag   = item.select_one("span.author")
        fecha_tag     = item.select_one("span.date")
        publisher_tag = item.select_one("span.publisher")

        titulo    = limpia_texto(titulo_tag.text)    if titulo_tag    else "NA"
        link      = BASE_URL + titulo_tag["href"]    if titulo_tag    else "NA"
        autores   = limpia_texto(autores_tag.text)   if autores_tag   else "NA"
        fecha     = limpia_texto(fecha_tag.text)     if fecha_tag     else "NA"
        editorial = limpia_texto(publisher_tag.text) if publisher_tag else "NA"

        resumen = extraer_resumen_completo(link) if link != "NA" else "NA"

        datos.append({
            "titulo":    titulo,
            "autores":   autores,
            "resumen":   resumen,
            "editorial": editorial,
            "fecha":     fecha,
            "link":      link
        })

        # time.sleep(0.1)  # ← puedes comentar o reducir esta pausa

    next_btn = soup.select_one("a.next-page-link")
    if next_btn and next_btn.get("href"):
        scrape_listing_page(BASE_URL + next_btn["href"])

if __name__ == "__main__":
    scrape_listing_page(START_URL)

    with open("articulos_upch_global.csv", "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=[
            "titulo","autores","resumen","editorial","fecha","link"
        ], quoting=csv.QUOTE_ALL)
        writer.writeheader()
        writer.writerows(datos)

    print(f"Se guardaron {len(datos)} artículos en 'articulos_upch_global.csv'")
# Out:
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=20
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=40
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=60
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=80
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=100
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=120
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=140
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=160
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=180
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=200
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=220
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=240
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=260
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=280
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=300
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=320
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=340
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=360
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=380
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=400
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=420
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=440
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=460
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=480
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=500
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=520
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=540
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=560
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=580
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=600
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=620
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=640
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=660
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=680
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=700
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=720
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=740
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=760
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=780
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=800
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=820
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=840
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=860
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=880
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=900
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=920
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=940
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=960
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=980
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1000
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1020
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1040
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1060
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1080
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1100
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1120
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1140
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1160
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1180
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1200
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1220
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1240
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1260
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1280
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1300
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1320
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1340
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1360
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1380
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1400
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1420
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1440
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1460
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1480
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1500
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1520
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1540
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1560
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1580
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1600
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1620
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1640
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1660
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1680
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1700
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1720
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1740
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1760
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1780
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1800
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1820
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1840
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1860
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1880
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1900
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1920
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1940
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1960
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=1980
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2000
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2020
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2040
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2060
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2080
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2100
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2120
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2140
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2160
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2180
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2200
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2220
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2240
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2260
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2280
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2300
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2320
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2340
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2360
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2380
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2400
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2420
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2440
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2460
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2480
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2500
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2520
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2540
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2560
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2580
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2600
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2620
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2640
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2660
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2680
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2700
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2720
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2740
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2760
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2780
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2800
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2820
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2840
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2860
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2880
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2900
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2920
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2940
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2960
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=2980
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3000
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3020
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3040
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3060
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3080
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3100
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3120
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3140
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3160
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3180
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3200
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3220
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3240
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3260
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3280
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3300
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3320
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3340
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3360
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3380
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3400
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3420
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3440
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3460
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3480
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3500
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3520
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3540
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3560
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3580
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3600
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3620
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3640
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3660
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3680
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3700
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3720
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3740
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3760
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3780
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3800
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3820
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3840
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3860
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3880
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3900
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3920
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3940
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3960
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=3980
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4000
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4020
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4040
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4060
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4080
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4100
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4120
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4140
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4160
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4180
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4200
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4220
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4240
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4260
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4280
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4300
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4320
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4340
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4360
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4380
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4400
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4420
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4440
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4460
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4480
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4500
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4520
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4540
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4560
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4580
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4600
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4620
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4640
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4660
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4680
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4700
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4720
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4740
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4760
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4780
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4800
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4820
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4840
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4860
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4880
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4900
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4920
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4940
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4960
# Scraping: https://repositorio.upch.edu.pe/handle/20.500.12866/1318/recent-submissions?offset=4980
# Se guardaron 4988 artículos en 'articulos_upch_global.csv'
